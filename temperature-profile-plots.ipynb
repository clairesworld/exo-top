# %%
# %matplotlib inline
import numpy as np
import math
from numpy import sqrt
import matplotlib.pyplot as plt

# %%
Tm = np.linspace(1000, 2000)

Ra_crit = 450
T_m0 = 1750
rho = 3500
c_v = 1142
a_rh = 2.54
k = 4
alpha = 2.5e-5
Ts = 250
kappa = 9.523809523809523e-07
g_sfc = 3.47 

# viscosity 
Ea = 300e3
eta0 = 1e21
T0 = 1600
R_b = 8.3144598 # universal gas constant in J mol −1 K −1

H0_0 = 1.6255113699999997e-8 # at t0
H0_1 = 8.689931245925946e-9 # present

H0_0ten = 1.62551137e-07
H0_1ten = 8.689931245925947e-08

labelsize=14

# %%
fig, axes = plt.subplots(1, 2, figsize=(10, 4))
labelsize=14

ax = axes[0]
H0 = H0_0
d_subs = ((-R_b*Tm**2*a_rh*k + sqrt(k*(2.0*Ea**2*H0*Tm*(Ea*Ra_crit*eta0*kappa*np.exp(Ea/(R_b*Tm) - Ea/(R_b*T0))/(R_b*Tm**2*a_rh*alpha*g_sfc*rho))**0.666666666666667 - 2.0*Ea**2*H0*Ts*(Ea*Ra_crit*eta0*kappa*np.exp(Ea/(R_b*Tm) - Ea/(R_b*T0))/(R_b*Tm**2*a_rh*alpha*g_sfc*rho))**0.666666666666667 - 2.0*Ea*H0*R_b*Tm**2*a_rh*(Ea*Ra_crit*eta0*kappa*np.exp(Ea/(R_b*Tm) - Ea/(R_b*T0))/(R_b*Tm**2*a_rh*alpha*g_sfc*rho))**0.666666666666667 + R_b**2*Tm**4*a_rh**2*k)))/(Ea*H0*(Ea*Ra_crit*eta0*kappa*np.exp(Ea/(R_b*Tm) - Ea/(R_b*T0))/(R_b*Tm**2*a_rh*alpha*g_sfc*rho))**(1/3)))
ax.plot(Tm, d_subs*1e-3, c='red', label='$H_{lith} = H_{mtl}$')
H0 = H0_0ten
d_subs = ((-R_b*Tm**2*a_rh*k + sqrt(k*(2.0*Ea**2*H0*Tm*(Ea*Ra_crit*eta0*kappa*np.exp(Ea/(R_b*Tm) - Ea/(R_b*T0))/(R_b*Tm**2*a_rh*alpha*g_sfc*rho))**0.666666666666667 - 2.0*Ea**2*H0*Ts*(Ea*Ra_crit*eta0*kappa*np.exp(Ea/(R_b*Tm) - Ea/(R_b*T0))/(R_b*Tm**2*a_rh*alpha*g_sfc*rho))**0.666666666666667 - 2.0*Ea*H0*R_b*Tm**2*a_rh*(Ea*Ra_crit*eta0*kappa*np.exp(Ea/(R_b*Tm) - Ea/(R_b*T0))/(R_b*Tm**2*a_rh*alpha*g_sfc*rho))**0.666666666666667 + R_b**2*Tm**4*a_rh**2*k)))/(Ea*H0*(Ea*Ra_crit*eta0*kappa*np.exp(Ea/(R_b*Tm) - Ea/(R_b*T0))/(R_b*Tm**2*a_rh*alpha*g_sfc*rho))**(1/3)))
ax.plot(Tm, d_subs*1e-3, c='orange', label='$H_{lith} = 10H_{mtl}$')
ax.set_xlabel('Temperature (K)',fontsize=labelsize)
ax.set_ylabel('Lid thickness (km)',fontsize=labelsize)
ax.set_xlim(Tm.min(), Tm.max())
ax.set_ylim(100, 1000)
ax.set_title('0 Ga',fontsize=labelsize)
ax.legend(frameon=False,fontsize=labelsize)

ax = axes[1]
H0 = H0_1
d_subs = ((-R_b*Tm**2*a_rh*k + sqrt(k*(2.0*Ea**2*H0*Tm*(Ea*Ra_crit*eta0*kappa*np.exp(Ea/(R_b*Tm) - Ea/(R_b*T0))/(R_b*Tm**2*a_rh*alpha*g_sfc*rho))**0.666666666666667 - 2.0*Ea**2*H0*Ts*(Ea*Ra_crit*eta0*kappa*np.exp(Ea/(R_b*Tm) - Ea/(R_b*T0))/(R_b*Tm**2*a_rh*alpha*g_sfc*rho))**0.666666666666667 - 2.0*Ea*H0*R_b*Tm**2*a_rh*(Ea*Ra_crit*eta0*kappa*np.exp(Ea/(R_b*Tm) - Ea/(R_b*T0))/(R_b*Tm**2*a_rh*alpha*g_sfc*rho))**0.666666666666667 + R_b**2*Tm**4*a_rh**2*k)))/(Ea*H0*(Ea*Ra_crit*eta0*kappa*np.exp(Ea/(R_b*Tm) - Ea/(R_b*T0))/(R_b*Tm**2*a_rh*alpha*g_sfc*rho))**(1/3)))
ax.plot(Tm, d_subs*1e-3, c='red')
H0 = H0_1ten
d_subs = ((-R_b*Tm**2*a_rh*k + sqrt(k*(2.0*Ea**2*H0*Tm*(Ea*Ra_crit*eta0*kappa*np.exp(Ea/(R_b*Tm) - Ea/(R_b*T0))/(R_b*Tm**2*a_rh*alpha*g_sfc*rho))**0.666666666666667 - 2.0*Ea**2*H0*Ts*(Ea*Ra_crit*eta0*kappa*np.exp(Ea/(R_b*Tm) - Ea/(R_b*T0))/(R_b*Tm**2*a_rh*alpha*g_sfc*rho))**0.666666666666667 - 2.0*Ea*H0*R_b*Tm**2*a_rh*(Ea*Ra_crit*eta0*kappa*np.exp(Ea/(R_b*Tm) - Ea/(R_b*T0))/(R_b*Tm**2*a_rh*alpha*g_sfc*rho))**0.666666666666667 + R_b**2*Tm**4*a_rh**2*k)))/(Ea*H0*(Ea*Ra_crit*eta0*kappa*np.exp(Ea/(R_b*Tm) - Ea/(R_b*T0))/(R_b*Tm**2*a_rh*alpha*g_sfc*rho))**(1/3)))
ax.plot(Tm, d_subs*1e-3, c='orange', label='$H_{lith} = 10H_{mtl}$')
ax.set_xlabel('Temperature (K)',fontsize=labelsize)
ax.set_ylabel('Lid thickness (km)',fontsize=labelsize)
ax.set_xlim(Tm.min(), Tm.max())
ax.set_ylim(100, 1000)
ax.set_title('4.5 Ga',fontsize=labelsize)


plt.tight_layout()
plt.savefig('d_T.png', bbox_inches='tight')

# %%
H0 = H0_0
z = np.linspace(-1000e3, 0)
H = H0
fig, axes = plt.subplots(1, 1, figsize=(7, 4))

ax = axes

Tm = 1300
d = ((-R_b*Tm**2*a_rh*k + sqrt(k*(2.0*Ea**2*H0*Tm*(Ea*Ra_crit*eta0*kappa*np.exp(Ea/(R_b*Tm) - Ea/(R_b*T0))/(R_b*Tm**2*a_rh*alpha*g_sfc*rho))**0.666666666666667 - 2.0*Ea**2*H0*Ts*(Ea*Ra_crit*eta0*kappa*np.exp(Ea/(R_b*Tm) - Ea/(R_b*T0))/(R_b*Tm**2*a_rh*alpha*g_sfc*rho))**0.666666666666667 - 2.0*Ea*H0*R_b*Tm**2*a_rh*(Ea*Ra_crit*eta0*kappa*np.exp(Ea/(R_b*Tm) - Ea/(R_b*T0))/(R_b*Tm**2*a_rh*alpha*g_sfc*rho))**0.666666666666667 + R_b**2*Tm**4*a_rh**2*k)))/(Ea*H0*(Ea*Ra_crit*eta0*kappa*np.exp(Ea/(R_b*Tm) - Ea/(R_b*T0))/(R_b*Tm**2*a_rh*alpha*g_sfc*rho))**(1/3)))
print(d)
eta = eta0*np.exp(Ea/R_b * (Tm**-1 - T0**-1))
deltaT_rh = -R_b*Tm**2/Ea
Tl = Tm + a_rh*deltaT_rh
delta_ubl = (Ra_crit*kappa*eta/(alpha*rho*g_sfc*(Tm-Tl)))**(1/3)  #(h)*(Ra_crit/Ra_rh)**beta
q_bl = k*(Tm-Tl)/delta_ubl
T_z = -H/(2*k)*(z)**2 - (q_bl + H*d)/k*(z) + Ts
ax.plot(T_z, z*1e-3, c='purple', label='$T_m = 1300$ K')
ax.axvline(x=Tl, ymin=0, ymax=1-d*1e-3/1000, c='purple', ls='--', lw=1)

Tm = 1500
d = ((-R_b*Tm**2*a_rh*k + sqrt(k*(2.0*Ea**2*H0*Tm*(Ea*Ra_crit*eta0*kappa*np.exp(Ea/(R_b*Tm) - Ea/(R_b*T0))/(R_b*Tm**2*a_rh*alpha*g_sfc*rho))**0.666666666666667 - 2.0*Ea**2*H0*Ts*(Ea*Ra_crit*eta0*kappa*np.exp(Ea/(R_b*Tm) - Ea/(R_b*T0))/(R_b*Tm**2*a_rh*alpha*g_sfc*rho))**0.666666666666667 - 2.0*Ea*H0*R_b*Tm**2*a_rh*(Ea*Ra_crit*eta0*kappa*np.exp(Ea/(R_b*Tm) - Ea/(R_b*T0))/(R_b*Tm**2*a_rh*alpha*g_sfc*rho))**0.666666666666667 + R_b**2*Tm**4*a_rh**2*k)))/(Ea*H0*(Ea*Ra_crit*eta0*kappa*np.exp(Ea/(R_b*Tm) - Ea/(R_b*T0))/(R_b*Tm**2*a_rh*alpha*g_sfc*rho))**(1/3)))
print(d)
eta = eta0*np.exp(Ea/R_b * (Tm**-1 - T0**-1))
deltaT_rh = -R_b*Tm**2/Ea
Tl = Tm + a_rh*deltaT_rh
delta_ubl = (Ra_crit*kappa*eta/(alpha*rho*g_sfc*(Tm-Tl)))**(1/3)  #(h)*(Ra_crit/Ra_rh)**beta
q_bl = k*(Tm-Tl)/delta_ubl
T_z = -H/(2*k)*(z)**2 - (q_bl + H*d)/k*(z) + Ts
ax.plot(T_z, z*1e-3, c='red', label='$T_m = 1500$ K')
ax.axvline(x=Tl, ymin=0, ymax=1-d*1e-3/1000,  c='red', ls='--', lw=1)


Tm = 1700
d = ((-R_b*Tm**2*a_rh*k + sqrt(k*(2.0*Ea**2*H0*Tm*(Ea*Ra_crit*eta0*kappa*np.exp(Ea/(R_b*Tm) - Ea/(R_b*T0))/(R_b*Tm**2*a_rh*alpha*g_sfc*rho))**0.666666666666667 - 2.0*Ea**2*H0*Ts*(Ea*Ra_crit*eta0*kappa*np.exp(Ea/(R_b*Tm) - Ea/(R_b*T0))/(R_b*Tm**2*a_rh*alpha*g_sfc*rho))**0.666666666666667 - 2.0*Ea*H0*R_b*Tm**2*a_rh*(Ea*Ra_crit*eta0*kappa*np.exp(Ea/(R_b*Tm) - Ea/(R_b*T0))/(R_b*Tm**2*a_rh*alpha*g_sfc*rho))**0.666666666666667 + R_b**2*Tm**4*a_rh**2*k)))/(Ea*H0*(Ea*Ra_crit*eta0*kappa*np.exp(Ea/(R_b*Tm) - Ea/(R_b*T0))/(R_b*Tm**2*a_rh*alpha*g_sfc*rho))**(1/3)))
print(d)
eta = eta0*np.exp(Ea/R_b * (Tm**-1 - T0**-1))
deltaT_rh = -R_b*Tm**2/Ea
Tl = Tm + a_rh*deltaT_rh
delta_ubl = (Ra_crit*kappa*eta/(alpha*rho*g_sfc*(Tm-Tl)))**(1/3)  #(h)*(Ra_crit/Ra_rh)**beta
q_bl = k*(Tm-Tl)/delta_ubl
T_z = -H/(2*k)*(z)**2 - (q_bl + H*d)/k*(z) + Ts
ax.plot(T_z, z*1e-3, c='orange', label='$T_m = 1700$ K')
ax.axvline(x=Tl, ymin=0, ymax=1-d*1e-3/1000,  c='orange', ls='--', lw=1)


Tm = 1900
d = ((-R_b*Tm**2*a_rh*k + sqrt(k*(2.0*Ea**2*H0*Tm*(Ea*Ra_crit*eta0*kappa*np.exp(Ea/(R_b*Tm) - Ea/(R_b*T0))/(R_b*Tm**2*a_rh*alpha*g_sfc*rho))**0.666666666666667 - 2.0*Ea**2*H0*Ts*(Ea*Ra_crit*eta0*kappa*np.exp(Ea/(R_b*Tm) - Ea/(R_b*T0))/(R_b*Tm**2*a_rh*alpha*g_sfc*rho))**0.666666666666667 - 2.0*Ea*H0*R_b*Tm**2*a_rh*(Ea*Ra_crit*eta0*kappa*np.exp(Ea/(R_b*Tm) - Ea/(R_b*T0))/(R_b*Tm**2*a_rh*alpha*g_sfc*rho))**0.666666666666667 + R_b**2*Tm**4*a_rh**2*k)))/(Ea*H0*(Ea*Ra_crit*eta0*kappa*np.exp(Ea/(R_b*Tm) - Ea/(R_b*T0))/(R_b*Tm**2*a_rh*alpha*g_sfc*rho))**(1/3)))
print(d)
eta = eta0*np.exp(Ea/R_b * (Tm**-1 - T0**-1))
deltaT_rh = -R_b*Tm**2/Ea
Tl = Tm + a_rh*deltaT_rh
delta_ubl = (Ra_crit*kappa*eta/(alpha*rho*g_sfc*(Tm-Tl)))**(1/3)  #(h)*(Ra_crit/Ra_rh)**beta
q_bl = k*(Tm-Tl)/delta_ubl
T_z = -H/(2*k)*(z)**2 - (q_bl + H*d)/k*(z) + Ts
ax.plot(T_z, z*1e-3, c='black', label='$T_m = 1900$ K')
ax.axvline(x=Tl, ymin=0, ymax=1-d*1e-3/1000,  c='black', ls='--', lw=1)

ax.legend(frameon=False,fontsize=labelsize)
ax.set_xlabel('Temperature (K)',fontsize=labelsize)
ax.set_ylabel('Depth (km)',fontsize=labelsize)
#ax.set_xlim(Tm.min(), Tm.max())
ax.set_ylim(-1000, 0)
ax.set_title('Steady state rectangular box model',fontsize=labelsize)

plt.tight_layout()
plt.savefig('T_z.png', bbox_inches='tight')
# Out:
# 654641.6125014554
# 627866.5094500268
# 474912.99962306954
# 266225.11427410884
