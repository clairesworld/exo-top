# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import hoggard
# %matplotlib inline

# %%
fig_path = 'figs/' # '/space/cmg76/hoggard_data/figs/' # office
file_path = '../../Downloads/' # '/space/cmg76/hoggard_data/' # office

hoggard.do(fig_path=fig_path, save=True, 
           file_path=file_path)
